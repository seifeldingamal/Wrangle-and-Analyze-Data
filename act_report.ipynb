# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Insights and Visaulisations

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %% [markdown]
# ### Does tweets with higher ratings recieve higher favourite counts ?

# %%
rating_median = df.rating_numerator.median()
low_rating = df.query('rating_numerator < @rating_median')
high_rating = df.query('rating_numerator > @rating_median')
mean_count_low = low_rating.favorite_count.mean()
mean_count_high = high_rating.favorite_count.mean()

# %%
locations = [1, 2]
heights = [mean_count_low, mean_count_high]
labels = ['Low', 'High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Favourite Count by Given Rating')
plt.xlabel('Given Rating')
plt.ylabel('Favourite Count');

# %% [markdown]
# ### Does tweets with higher ratings recieve higher retweet counts ?

# %%
rating_median = df.rating_numerator.median()
low_rating = df.query('rating_numerator < @rating_median')
high_rating = df.query('rating_numerator > @rating_median')
mean_count_low = low_rating.retweet_count.mean()
mean_count_high = high_rating.retweet_count.mean()

# %%
locations = [1, 2]
heights = [mean_count_low, mean_count_high]
labels = ['Low', 'High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Retweet Count by Given Rating')
plt.xlabel('Given Rating')
plt.ylabel('Retweet Count');

# %% [markdown]
# ### What is the most frequent Dog name ?

# %%
df.query('name != "None"').name.describe()
# Out:
# count        1345
# unique        912
# top       Charlie
# freq           10
# Name: name, dtype: object

# %% [markdown]
# ### What is the most frequent Dog breeds ?

# %%
df.prediction.describe()
# Out:
# count                 1964
# unique                 319
# top       Golden Retriever
# freq                   156
# Name: prediction, dtype: object

# %%
top_preds = df.prediction.value_counts()
top_preds = top_preds[top_preds > 40]
top_preds.plot.bar(color = 'red')
plt.title('Top Dog Prediction count');

# %%
pd.set_option('display.max_colwidth', -1)
df.query('prediction == "Pomeranian"').expanded_urls
# Out:
# 234     https://twitter.com/dog_rates/status/816091915477250048/photo/1 , https://twitter.com/dog_rates/status/816091915477250048/photo/1 , https://twitter.com/dog_rates/status/816091915477250048/photo/1 , https://twitter.com/dog_rates/status/816091915477250048/photo/1
# 261     https://twitter.com/dog_rates/status/809220051211603969/photo/1 , https://twitter.com/dog_rates/status/809220051211603969/photo/1
# 385     https://twitter.com/dog_rates/status/773922284943896577/photo/1
# 408     https://twitter.com/dog_rates/status/768970937022709760/video/1
# 492     https://twitter.com/dog_rates/status/749395845976588288/photo/1 , https://twitter.com/dog_rates/status/749395845976588288/photo/1
# 546     https://twitter.com/dog_rates/status/732726085725589504/photo/1
# 576     https://twitter.com/dog_rates/status/721503162398597120/photo/1 , https://twitter.com/dog_rates/status/721503162398597120/photo/1 , https://twitter.com/dog_rates/status/721503162398597120/photo/1 , https://twitter.com/dog_rates/status/721503162398597120/photo/1
# 596     https://twitter.com/dog_rates/status/716791146589110272/photo/1
# 642     https://twitter.com/dog_rates/status/708738143638450176/photo/1
# 688     https://twitter.com/dog_rates/status/701981390485725185/photo/1
# 698     https://twitter.com/dog_rates/status/700462010979500032/photo/1
# 785     https://twitter.com/dog_rates/status/687826841265172480/photo/1 , https://twitter.com/dog_rates/status/687826841265172480/photo/1 , https://twitter.com/dog_rates/status/687826841265172480/photo/1 , https://twitter.com/dog_rates/status/687826841265172480/photo/1
# 797     https://twitter.com/dog_rates/status/686050296934563840/photo/1
# 842     https://twitter.com/dog_rates/status/681193455364796417/photo/1 , https://twitter.com/dog_rates/status/681193455364796417/photo/1
# 846     https://twitter.com/dog_rates/status/680913438424612864/photo/1
# 954     https://twitter.com/dog_rates/status/673345638550134785/photo/1
# 995     https://twitter.com/dog_rates/status/671520732782923777/photo/1
# 1020    https://twitter.com/dog_rates/status/670804601705242624/photo/1
# 1062    https://twitter.com/dog_rates/status/669683899023405056/photo/1
# 1121    https://twitter.com/dog_rates/status/667886921285246976/photo/1
# 1129    https://twitter.com/dog_rates/status/667544320556335104/photo/1
# 1165    https://twitter.com/dog_rates/status/786709082849828864/photo/1
# 1169    https://twitter.com/dog_rates/status/890729181411237888/photo/1 , https://twitter.com/dog_rates/status/890729181411237888/photo/1
# 1286    https://twitter.com/dog_rates/status/718631497683582976/photo/1
# 1328    https://twitter.com/dog_rates/status/695816827381944320/photo/1
# 1411    https://twitter.com/dog_rates/status/675822767435051008/photo/1
# 1437    https://twitter.com/dog_rates/status/674024893172875264/photo/1
# 1484    https://twitter.com/dog_rates/status/670717338665226240/photo/1
# 1496    https://twitter.com/dog_rates/status/669926384437997569/photo/1
# 1601    https://twitter.com/dog_rates/status/702539513671897089/photo/1 , https://twitter.com/dog_rates/status/702539513671897089/photo/1 , https://twitter.com/dog_rates/status/702539513671897089/photo/1
# 1616    https://twitter.com/dog_rates/status/674082852460433408/photo/1
# 1672    https://twitter.com/dog_rates/status/831939777352105988/photo/1
# 1709    https://twitter.com/dog_rates/status/821107785811234820/photo/1
# 1738    https://twitter.com/dog_rates/status/685307451701334016/photo/1
# 1754    https://twitter.com/dog_rates/status/822462944365645825/photo/1 , https://twitter.com/dog_rates/status/822462944365645825/photo/1 , https://twitter.com/dog_rates/status/822462944365645825/photo/1 , https://twitter.com/dog_rates/status/822462944365645825/photo/1
# 1803    https://twitter.com/dog_rates/status/689905486972461056/photo/1 , https://twitter.com/dog_rates/status/689905486972461056/photo/1 , https://twitter.com/dog_rates/status/689905486972461056/photo/1 , https://twitter.com/dog_rates/status/689905486972461056/photo/1
# 1823    https://twitter.com/dog_rates/status/681654059175129088/photo/1
# 1835    https://twitter.com/dog_rates/status/674737130913071104/photo/1
# 1875    https://twitter.com/dog_rates/status/727524757080539137/photo/1 , https://twitter.com/dog_rates/status/727524757080539137/photo/1
# 1929    https://twitter.com/dog_rates/status/674638615994089473/photo/1
# 1935    https://twitter.com/dog_rates/status/728035342121635841/photo/1 , https://twitter.com/dog_rates/status/728035342121635841/photo/1
# Name: expanded_urls, dtype: object

# %% [markdown]
# ### Skewness of Ratings

# %%
df.rating_numerator.value_counts().hist()
plt.axis([-25,200,0,20]);

# %% [markdown]
# ### Skewness of Favourite Count

# %%
df.favorite_count.hist();

# %% [markdown]
# ### Skewness of Retweet Count

# %%
df.retweet_count.hist();

# %% [markdown]
# ### A chart for different source of tweets

# %%
df.source.value_counts().plot.pie(subplots=True);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1964 entries, 0 to 1963
# Data columns (total 14 columns):
# tweet_id             1964 non-null int64
# timestamp            1964 non-null object
# source               1964 non-null object
# text                 1964 non-null object
# expanded_urls        1964 non-null object
# rating_numerator     1964 non-null float64
# name                 1958 non-null object
# dog_stage            1964 non-null object
# retweet_count        1964 non-null int64
# favorite_count       1964 non-null int64
# img_num              1964 non-null int64
# prediction           1964 non-null object
# prediction_config    1964 non-null float64
# prediction_dog       1964 non-null bool
# dtypes: bool(1), float64(2), int64(4), object(7)
# memory usage: 201.5+ KB
